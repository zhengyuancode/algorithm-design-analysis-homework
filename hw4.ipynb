# %% [markdown]
# ## algorithm design and anlysis-2025 spring  homework 4
# **Deadline**：2025.5.14
#
# **name**:
#
#
# note：
# ---
# 1. 带有\*的题目，申请免上课的同学，必须完成，其他同学选作；
# 2. 请独立完成，如求助了他人或者大模型，请著明，并且不可省略算法分析部分；
# 4. 如若作答有雷同，全部取消成绩；
# 3. 需要书面作答的题目，可以通过引用图片的形式添加，但是注意上传项目时包含所引用的图片的源文件；
# 4. $log_n$ 默认表示$log_2{n}$;

# %% [markdown]
# ## 问题 1
# **最小生成树（Minimum Spanning Tree）**
#
# 设  **G**  为一个带权重的连通无向图，且所有边的权重均不相等。令$e_i$ 为权重第 $i$ 小的边。最小生成树（MST）是否必须包含 $e_1$ ? 同理，是否必须包含 $e_2$ 和 $e_3$ ? 若必须包含，请给出证明；否则，请构造反例。需从基本原理论证，不能依赖割引理(cut lemma) 或 Prim/Kruskal算法的正确性。

# %% [markdown]
# answer:
#
# $e_1$和$e_2$必须包含，$e_3$不一定包含
#
#
#
# 对于给定的连通无向图G，所有边的权重互不相等,接下来分三部分证明
#
# 1. 必须包含 $e_1$（权重最小的边）
#
# 证明：假设存在一个生成树T不包含$e_1$。将$e_1$加入T中会形成一个环，且该环中至少存在一条边e′的权重大于$e_1$。
#
# 用$e_1$替换e′后，得到的新生成树总权重更小，与T是最小生成树矛盾。因此，MST必须包含$e_1$。
#
# 2. 必须包含 $e_2$（权重第二小的边）
#
# 证明：假设存在生成树T不包含$e_2$。将$e_2$加入T中会形成环。
#
# 由于所有边权重不同且$e_2$是第二小的边，该环中至少存在一条边e′的权重大于$e_2$否则T中已存在更小的边连接$e_2$的端点）。
#
# 替换e′为$e_2$后，总权重更小，矛盾。因此，MST必须包含$e_2$。
#
# 3. 不必须包含 $e_3$（权重第三小的边）
#
# 反例：考虑三个顶点A、B、C，边权为AB=1（e₁）、AC=2（e₂）、BC=3（e₃）。
#
# MST选择AB和AC，总权重为3。此时e₃（BC=3）未被包含。
# ![q1](./fig/answer/hw4-q1.jpg)

# %% [markdown]
# ## 问题 2
# **瓶颈生成树（Bottleneck Spanning Tree）**
#
# 带有权重的无向图 $G(V,E,w)$ 的瓶颈生成树，表现为：在所有生成树中，最大权重边的权重值最小。即，BST $T$ 最小化瓶颈损失 $c(T)=max_{e \in T}{w(e)}$。
#
# 1. 证明 $G$ 的每一个最小生成树（MST）都是瓶颈生成树（BST）
# 2. 设计一个线性时间复杂度的算法：， 对于一个图 $G(V,E,w)$ 和一个整数 $b$，判断图 $ G$ 是否存在一个瓶颈生成树，其最大权重边的权重不超过 $b$，分析算法设计思路，并基于python编程实现。
# 3. 设计一个线性时间复杂度的算法：对于给定的图 $G(V,E,w)$，找到其瓶颈生成树，分析算法设计思路，并基于python编程实现。

# %% [markdown]
# idea 1：
# ![q2.1](./fig/answer/hw4-q2.jpg)

# %% [markdown]
# idea 2:算法设计思路
#
# 瓶颈生成树（BST） 的定义是：所有生成树中最大边权最小的那个。若存在一个 BST，其最大边权不超过 b，则需满足图中存在一种生成树，其所有边的权重均 ≤b，并且这些边能连通所有顶点。
#
# 过滤边，保留所有边权 ≤b 的边。
#
# 使用并查集（Union-Find）结构，逐步合并这些边的顶点。如果最终所有顶点属于同一个连通分量，则说明 G′中存在一棵生成树（即 BST），其最大边权为b。
#
# 若子图 G′的边权均 ≤b，且能连通所有顶点，则必然存在一棵生成树，其最大边权 ≤b。反之，若 G′ 无法连通所有顶点，则不存在满足条件的BST。
#
# 所以若所有顶点连通，返回 True；否则返回 False。
#
# 时间复杂度分析：
#
# 边过滤：
# 遍历所有边（共 m 条），筛选出 m′ ≤ m 条符合条件的边，时间复杂度为$O(m)$。
#
# 并查集操作：
# 对每条符合条件的边执行一次 union 操作（最多 m′ 次）。
# find 和 union 操作的时间复杂度为 $O(α(n))$，其中 α(n) 是阿克曼函数的反函数（近似常数，通常 α(n)≤5）。
#
# 所以总体并查集操作时间复杂度为 $O(m′⋅α(n))$。
#
# 连通性检查：
# 最终遍历所有顶点（共 n 个），检查是否连通，时间复杂度为$O(n)$。
#
# 总时间复杂度：$O(m+m′⋅α(n)+n)$。由于 m′≤m，且 α(n) 为常数，可简化为 $O(m+n)$（线性时间复杂度）。

# %%
# add your code here
class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
    
    def find(self, x):
        while self.parent[x] != x:
            self.parent[x] = self.parent[self.parent[x]]  # 路径压缩
            x = self.parent[x]
        return x
    
    def union(self, x, y):
        fx, fy = self.find(x), self.find(y)
        if fx == fy:
            return False
        self.parent[fy] = fx
        return True

def has_bottleneck_spanning_tree(graph, b, n):
    """
    graph: 列表，元素为三元组 (u, v, w)
    b: 整数，最大边权限制
    n: 顶点数
    返回值：布尔值，是否存在满足条件的BST
    """
    # 过滤边权 <= b 的边
    edges = [e for e in graph if e[2] <= b]
    
    uf = UnionFind(n)
    for u, v, _ in edges:
        uf.union(u, v)
    
    # 检查所有顶点是否连通
    roots = set(uf.find(i) for i in range(n))
    return len(roots) == 1

# 示例图（顶点编号为0~3）
graph = [
    (0, 1, 1), (0, 2, 2), (0, 3, 3),
    (1, 2, 4), (2, 3, 5)
]
b = 3
n = 4  
print(has_bottleneck_spanning_tree(graph, b, n)) 

# algorithm of the liear time complexity :O(m+n)
# Out:
# True

# %% [markdown]
# idea 3:算法设计思路
#
# 最小生成树（MST）一定是瓶颈生成树（BST）。因此，只需构造 MST 即可得到 BST。
#
# 使用 Kruskal 算法 或 Prim 算法 构造 MST。
# 这里采用Kruskal 算法，边排序，将所有边按权重从小到大排序，依次选择最小边，使用并查集合并顶点，直到所有顶点连通。
#
# 当生成树包含 n−1 条边时，算法终止。
#
# Kruskal 算法构造的 MST 的最大边权一定是最小的，因此满足 BST 的定义。
#
#
# 时间复杂度分析
#
# 并查集操作：
#
# 每次 find 和 union 操作的时间复杂度为 $O(α(n))$，其中 $α(n)$ 是阿克曼函数的反函数（近似常数），最多执行 m 次操作，时间复杂度为 $O(m⋅α(n))$。
#
# 总时间复杂度：总时间复杂度为 $O(m⋅α(n))$，可视为线性。

# %%
# add your code here
class UnionFind:
    def __init__(self, n):
        self.parent = list(range(n))
    
    def find(self, x):
        while self.parent[x] != x:
            self.parent[x] = self.parent[self.parent[x]]  # 路径压缩
            x = self.parent[x]
        return x
    
    def union(self, x, y):
        fx, fy = self.find(x), self.find(y)
        if fx == fy:
            return False
        self.parent[fy] = fx
        return True

def find_bottleneck_spanning_tree(graph, n):
    """
    输入：
        graph: 列表，元素为三元组 (u, v, w)
        n: 顶点数
    输出：
        返回瓶颈生成树的边列表
    """
    # 按边权从小到大排序
    graph.sort(key=lambda x: x[2])
    
    uf = UnionFind(n)
    mst_edges = []
    for u, v, w in graph:
        if uf.union(u, v):
            mst_edges.append((u, v, w))
            if len(mst_edges) == n - 1:
                break
    return mst_edges

# 示例图（顶点编号为 0~3）
graph = [
    (0, 1, 1),
    (0, 2, 2),
    (0, 3, 3),
    (1, 2, 4),
    (2, 3, 5)
]
n = 4  # 顶点数

# 调用函数，构造瓶颈生成树
bst_edges = find_bottleneck_spanning_tree(graph, n)

# 输出结果
print("瓶颈生成树的边：")
for edge in bst_edges:
    print(edge)
    
# algorithm of the liear time complexity :O(m⋅α(n))
# Out:
# 瓶颈生成树的边：
# (0, 1, 1)
# (0, 2, 2)
# (0, 3, 3)

# %% [markdown]
# ## 问题 3
#
# **道路网（Road Network）**
#
# 假设有一个以图 $ G(V, E, l) $ 表示的道路网络，连接了一组城市 $ V $。我们假设该网络是有向的，并且每条道路 $(u, v) \in E$ 都有一个非负的长度 $ l(u, v) $。一条新的道路即将被建造，因此有一个列表 $ E' $ 包含它可以连接的城市对。每对 $(u, v) \in E'$ 都有一个对应的长度 $ l'(u, v) $。我们希望选择一对城市，使得两个城市 $ s, t \in V $ 之间的距离减少最大。请为此问题编写一个高效的算法，并详细解释算法的正确性和复杂度。

# %% [markdown]
# idea：
#
# 给定一个有向图 $ G(V, E, l) $ 表示的道路网络，其中每条道路 $(u, v) \in E$ 有一个非负长度 $ l(u, v) $。现有一个新的道路列表 $ E' $，每条道路 $(u, v) \in E'$ 也有对应的长度 $ l'(u, v) $。目标是选择一条新道路 $(u, v) \in E'$，使得添加该道路后，某个固定城市对 $ s, t \in V $ 之间的最短距离减少最大。
#
# 预处理使用 Dijkstra 算法计算从源城市 s 到所有其他节点的最短距离 $d_s$。然后构造原图的转置图（边方向反转），并使用 Dijkstra 算法计算从目标城市 t 到所有其他节点的最短距离 $d_t$，即原图中所有节点到 t 的最短距离。
#
# 评估候选边：
#
# 对于每条候选边 $(u,v)∈E'$，如果 $d_s[u]$ 和 $d_t[v]$ 都为有限值，则添加该边后，从 s 到 t 的新路径长度为 $d_s[u]+l'(u,v)+d_t[v]$。
#
# 如果该新路径长度小于原最短距离 $d_s[t]$，则计算其减少量，并记录最大减少量及对应的边。
#
# 如果原最短距离 $d_s[t]$ 为无穷大（即 s 不可达 t），则寻找候选边中能使得 s 到 t 可达且路径最短的边。
#
# **算法正确性**
#
# 通过两次 Dijkstra 算法，分别计算从s 出发和从 t 出发的最短路径，确保所有候选边的评估基于准确的最短路径信息。通过预处理结果，可以快速计算每条候选边对 s 到 t 最短路径的潜在影响，避免重新运行完整的 Dijkstra 算法，从而提高效率。当原最短路径不可达时，通过寻找候选边中最小的可行路径长度，确保算法能处理所有可能情况。
#
# **时间复杂度分析**
#
# Dijkstra 算法的时间复杂度为 $O(E+VlogV)$，其中 E 是图的边数，V 是节点数。
#
# 预处理时运行两次 Dijkstra，时间复杂度为 $O(2(E+VlogV))$。
#
# 遍历所有候选边 M 次，每次计算为常数时间，总时间为 $O(M)$。
#
# 因此，总的时间复杂度为：$O(E+VlogV+M)$

# %%
# add your code here
import heapq

def dijkstra(graph, start, n):
    INF = float('inf')
    dist = [INF] * n
    dist[start] = 0
    heap = [(0, start)]
    visited = set()

    while heap:
        current_dist, u = heapq.heappop(heap)
        if u in visited:
            continue
        visited.add(u)
        for v, w in graph[u]:
            if dist[v] > current_dist + w:
                dist[v] = current_dist + w
                heapq.heappush(heap, (dist[v], v))
    return dist

def find_best_new_road(n, original_edges, E_prime, s, t):
    # 构建原图的邻接表
    graph = [[] for _ in range(n)]
    for u, v, l in original_edges:
        graph[u].append((v, l))

    # 构建转置图
    transposed_graph = [[] for _ in range(n)]
    for u, v, l in original_edges:
        transposed_graph[v].append((u, l))

    # 计算s到各点的最短距离
    d_s = dijkstra(graph, s, n)
    # 计算各点到t的最短距离（转置图中t到各点的最短距离）
    d_t = dijkstra(transposed_graph, t, n)

    original_dist = d_s[t]
    best_edge = None
    max_reduction = 0

    if original_dist != float('inf'):
        # 原来的s到t是可达的
        for u, v, l in E_prime:
            if d_s[u] == float('inf') or d_t[v] == float('inf'):
                continue
            candidate = d_s[u] + l + d_t[v]
            if candidate < original_dist:
                reduction = original_dist - candidate
                if reduction > max_reduction:
                    max_reduction = reduction
                    best_edge = (u, v, l)
    else:
        # 原来的s到t不可达，寻找是否有候选边可以使得可达
        min_new_dist = float('inf')
        for u, v, l in E_prime:
            if d_s[u] == float('inf') or d_t[v] == float('inf'):
                continue
            candidate = d_s[u] + l + d_t[v]
            if candidate < min_new_dist:
                min_new_dist = candidate
                best_edge = (u, v, l)

    return best_edge


if __name__ == "__main__":
    n = 4
    original_edges = [(0, 1, 1), (1, 2, 2), (2, 3, 3), (0, 3, 100)]
    E_prime = [(0, 2, 10), (1, 3, 1)]
    s = 0
    t = 3

    best_edge = find_best_new_road(n, original_edges, E_prime, s, t)
    print("最佳新道路:", best_edge)
    
    # algorithm of the liear time complexity :O(E+VlogV+M)
# Out:
# 最佳新道路: (1, 3, 1)

# %% [markdown]
# ## 问题 4
#
# **逃离问题**
#
# 一个 $ n \times n $ 的网格是一个无向图，由 $ n $ 行和 $ n $ 列的顶点组成，如下图所示。我们用 $(i,j)$ 表示第 $ i $ 行和第 $ j $ 列的顶点。除了边界顶点，网格中的所有顶点都有四个邻居，即满足 $ i = 1, i = n, j = 1 $ 或 $ j = n $ 的点 $(i,j)$。
#
# 给定网格中的 $ m \leq n^2 $ 个起点 $(x_1, y_1), (x_2, y_2), \cdots , (x_m, y_m)$，逃离问题是确定是否存在 $ m $ 条顶点不相交的路径（即路径之间不相交），从这些起点到边界上的任意 $ m $ 个不同点。例如，图1中的网格存在逃离。
#
# (1) 该问题可以看作是一个最大流问题。考虑一个流网络，其中顶点和边都有容量。也就是说，进入任何给定顶点的总正流量受到容量限制。证明在具有边和顶点容量的网络中确定最大流可以简化为在具有可比大小的普通流网络上的最大流问题。更准确地说，你需要将一个具有顶点和边容量的网络 $ G = (V,E) $ 转换为另一个仅具有边容量的网络 $ G' = (V', E') $，使得两个网络上的最大流相同，并且你构建的新网络具有 $ V' = O(V) $ 个顶点和 $ E' = O(E) $ 条边。你可以假设网络是连通的。
#
# (2) 描述一个解决逃离问题的高效算法，并分析其运行时间。
#
#
# <div align="center"> <img alt="图片" src="./fig/escepe-p.png"> </div>
# <center> 图2. 逃脱问题网格，起始顶点为黑色，其他网格顶点为白色</center>

# %% [markdown]
# idea：
#
# **问题建模与算法设计**
#
# (1) 顶点与边容量网络的等价转换
#
# 转换方法：
#
# - 顶点拆分：
# 每个顶点 v 拆分为两个顶点 $v_i$（输入）和 $v_o$（输出）。添加一条边 $(v_i,v _o)$，其容量等于原顶点的容量 c(v)。
#
# - 边重定向：
# 对于原图中的每条边 (u,v)，将其替换为 $(u_o,v_i)$，容量保持不变。
#
# - 结果网络：
# 新网络 $G'$ 的顶点数 $∣V'∣=2∣V∣$，边数$|E'∣=∣E∣+∣V∣$。最大流问题在 G 和 G' 上等价。
#
# (2) 逃离问题的高效算法
#
# - 构建流网络：
# 源点s连接到所有起点，容量为 1。每个顶点拆分为 $v_i$ 和 $v_o$，中间边容量为 1。边界顶点连接到汇点 t，容量为 1。每个顶点与其四个邻居之间添加双向边，容量为 1。
#
# - 求解最大流：
# 使用 Edmonds-Karp 算法计算从 s 到 t 的最大流。
#
# 如果最大流等于起点数量 m，则存在 m 条不相交路径。
#
# **时间复杂度分析**
#
# - 顶点拆分与网络构建
#
#     顶点数：$O(n^2)$,边数：$O(n^2)$（顶点拆分）+ $O(n^2)$（邻接边） = $O(n^2)$
#
# - 最大流算法（Edmonds-Karp）
#
#     时间复杂度：$O(V'E'^2)=O(n^2⋅(n^2)^2)=O(n^6)$
#
# 因此总时间复杂度：$O(n^6)$

# %%
# add your code here
from collections import deque

class FlowNetwork:
    def __init__(self, n):
        self.n = n
        self.graph = [[] for _ in range(n)]
    
    def add_edge(self, u, v, capacity):
        self.graph[u].append([v, capacity, len(self.graph[v])])
        self.graph[v].append([u, 0, len(self.graph[u])-1])
    
    def bfs(self, s, t, parent, edge_indices):
        visited = [False] * self.n
        queue = deque([s])
        visited[s] = True
        parent[s] = -1
        edge_indices[s] = -1
        
        while queue:
            u = queue.popleft()
            for i, (v, capacity, rev_idx) in enumerate(self.graph[u]):
                if not visited[v] and capacity > 0:
                    queue.append(v)
                    visited[v] = True
                    parent[v] = u
                    edge_indices[v] = i
                    if v == t:
                        return True
        return False
    
    def max_flow(self, s, t):
        parent = [-1] * self.n
        edge_indices = [-1] * self.n
        max_flow = 0
        
        while self.bfs(s, t, parent, edge_indices):
            path_flow = float('inf')
            v = t
            while v != s:
                u = parent[v]
                path_flow = min(path_flow, self.graph[u][edge_indices[v]][1])
                v = u
            
            v = t
            while v != s:
                u = parent[v]
                edge_idx = edge_indices[v]
                rev_idx = self.graph[u][edge_idx][2]
                # 更新正向边和反向边
                self.graph[u][edge_idx][1] -= path_flow
                self.graph[v][rev_idx][1] += path_flow
                v = u
            
            max_flow += path_flow
        
        return max_flow

def can_escape(grid_size, start_points):
    num_vertices = grid_size * grid_size * 2
    source = num_vertices
    sink = num_vertices + 1
    total_vertices = num_vertices + 2
    network = FlowNetwork(total_vertices)
    
    for i in range(grid_size):
        for j in range(grid_size):
            vin = i * grid_size + j
            vout = vin + grid_size * grid_size
            # 顶点容量限制：1
            network.add_edge(vin, vout, 1)
    
    # 源点连接到起点
    for x, y in start_points:
        vin = x * grid_size + y
        network.add_edge(source, vin, 1)
    
    # 边界点连接到汇点
    for i in range(grid_size):
        for j in range(grid_size):
            vin = i * grid_size + j
            vout = vin + grid_size * grid_size
            if i == 0 or i == grid_size - 1 or j == 0 or j == grid_size - 1:
                network.add_edge(vout, sink, 1)
    
    # 添加网格内的边（拆分为 in-out）
    for i in range(grid_size):
        for j in range(grid_size):
            vin = i * grid_size + j
            vout = vin + grid_size * grid_size
            # 上
            if i > 0:
                neighbor_vin = (i - 1) * grid_size + j
                network.add_edge(vout, neighbor_vin, 1)
            # 下
            if i < grid_size - 1:
                neighbor_vin = (i + 1) * grid_size + j
                network.add_edge(vout, neighbor_vin, 1)
            # 左
            if j > 0:
                neighbor_vin = i * grid_size + (j - 1)
                network.add_edge(vout, neighbor_vin, 1)
            # 右
            if j < grid_size - 1:
                neighbor_vin = i * grid_size + (j + 1)
                network.add_edge(vout, neighbor_vin, 1)
    
    max_flow = network.max_flow(source, sink)
    return max_flow == len(start_points)


if __name__ == "__main__":
    grid_size = 4
    start_points = [(0, 0), (1, 1), (2, 2), (3, 3)]
    result = can_escape(grid_size, start_points)
    print("是否可逃离:", result)
    
# algorithm of the liear time complexity :O(n^6)
# Out:
# 是否可逃离: True
