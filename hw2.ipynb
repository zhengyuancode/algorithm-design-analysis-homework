# %% [markdown]
# ## algorithm design and anlysis-2025 spring  homework 2
# **Deadline**：2025.5.14
#
# **name**:
#
#
# note：
# ---
# 1. 带有\*的题目，申请免上课的同学，必须完成，其他同学选作；
# 2. 请独立完成，如求助了他人或者大模型，请著明，并且不可省略算法分析部分；
# 4. 如若作答有雷同，全部取消成绩；
# 3. 需要书面作答的题目，可以通过引用图片的形式添加，但是注意上传项目时包含所引用的图片的源文件；
# 4. $log_n$ 默认表示$log_2{n}$;

# %% [markdown]
# ## 问题 1
#
# > 给定一个已排序的链表的头 `head` ， *删除所有重复的元素，使每个元素只出现一次* 。返回 *已排序的链表* 。链表的类如下所示：
#
# ```python
# class NodeList:
#     def __init__(self, val=None, right=None):
#         self.val   = val
#         self.right = right
# ```
#
# 输入是一个数组，你首先需要将数组转化为链表，然后删除链表中的重复元素，再遍历链表元素，以一个数组的形式返回。请设计一个算法解决上述任务，分析算法设计思路，计算时间复杂度, 并基于python编程实现。
#
# e.g.  输入：head=[1, 1, 2, 3, 3]   输出：[1, 2, 3]
#
# ![image-20240502110020439](./fig/hw2q1.png)

# %% [markdown]
# idea：算法设计与实现
#
# 链表构建，将输入数组通过 array_to_linked_list 函数转换为单链表，时间复杂度 $O(n)$。
#
# 删除重复元素时，使用指针 current 遍历链表，逐个检查当前节点 current.val 与下一个节点 current.right.val 的值是否相同。若相同，则跳过下一个节点（current.right = current.right.right）；若不同，则指针后移（current = current.right）。由于链表已排序，重复元素必相邻，因此无需额外存储结构，直接逐对比较即可。
#
# 通过 linked_list_to_array 遍历处理后的链表，将其转为数组形式返回。
#
# 时间复杂度分析
#
# 链表构建：$O(n)$
#
# 删除重复：$O(n)$（每个节点最多被访问两次）
#
# 结果转换：$O(n)$
#
# 总时间复杂度：$O(n)$

# %%
# add your idea here
class NodeList:
    def __init__(self, val=None, right=None):
        self.val = val
        self.right = right

def array_to_linked_list(arr):
    if not arr:
        return None
    head = NodeList(arr[0])
    current = head
    for value in arr[1:]:
        current.right = NodeList(value)
        current = current.right
    return head

def delete_duplicates(head):
    if not head:
        return None
    current = head
    while current and current.right:
        if current.val == current.right.val:
            current.right = current.right.right
        else:
            current = current.right
    return head

def linked_list_to_array(head):
    result = []
    current = head
    while current:
        result.append(current.val)
        current = current.right
    return result

def remove_duplicates_from_sorted_list(nums):
    head = array_to_linked_list(nums)
    head = delete_duplicates(head)
    return linked_list_to_array(head)

# 示例
input_nums = [1, 1, 2, 3, 3]
output = remove_duplicates_from_sorted_list(input_nums)
print(output) 

# your algorithm time complexity is:O(n)
# Out:
# [1, 2, 3]

# %% [markdown]
# ## 问题 2
#
# > 下面是一个经典的算法问题：
# >
# > - 给定包含n个整数的一个整数数组 `nums` 和一个整数目标值 `target`，请你在该数组中找出 **和为目标值** *`target`* 的那 **两个** 整数，并返回它们的**数组下标**。假设每种输入只会对应一个答案。但是，数组中同一个元素在答案里不能重复出现。你可以按任意顺序返回答案。
# >
# > 由于要多次查找数组中元素的位置，为了提高查询效率可以使用哈希表来存储数组中的数据，在哈希表中查询一个元素的复杂度为O(1)。 已知python中的字典是使用哈希表实现的，即使用`dict[key]`查询对应的value时间复杂度为O(1), python提供了查询字典是否包含某个key的功能：`key in dict`，时间复杂度也是O(1)
#
# 请根据上面信息，设计一个时间复杂度为O(n) 的算法，解决上述算法问题
#
# e.g.
#
# 输入：nums=[2,7,11,15], target=9， 输出：[0，1]
#
# 输入：nums=[3,2,4], target=6, 输出：[1,2]
#
# 输入：nums=[3,3], target=6,  输出：[0,1]

# %% [markdown]
# idea:算法设计与实现
#
# 为了解决这个问题，我们可以利用哈希表（Python中的字典）来存储数组中每个值的索引。这样可以在一次遍历过程中完成查找和存储操作，从而将时间复杂度优化到 $O(n)$。
#
# 首先创建一个空字典 num_dict，用于存储数组元素及其对应的下标。
#
# 然后遍历数组 nums，对于每一个元素 nums[i]，计算目标值与当前元素的差值 complement = target - nums[i]。检查 complement 是否已经存在于字典 num_dict 中，如果存在，则说明找到了满足条件的两个数，返回它们的下标 [num_dict[complement], i]。如果不存在，则将当前元素 nums[i] 和其下标 i 存入字典中。
#
# 由于题目保证每组输入有且仅有一个解，因此无需处理未找到的情况。
#
# 时间复杂度分析
#
# 遍历数组：$O(n)$，其中 n 是数组的长度。
#
# 字典操作（插入和查找）：每次操作的时间复杂度是 $O(1)$，总共进行 $O(n)$ 次操作。 总时间复杂度：$O(n)$

# %%
# add your idea here
def two_sum(nums, target):
    num_dict = {}
    for i, num in enumerate(nums):
        complement = target - num
        if complement in num_dict:
            return [num_dict[complement], i]
        num_dict[num] = i
    
    
print(two_sum([2, 7, 11, 15], 9))  
print(two_sum([3, 2, 4], 6))       
print(two_sum([3, 3], 6))          

# your algorithm time complexity is: O(n)
# Out:
# [0, 1]
# [1, 2]
# [0, 1]

# %% [markdown]
# ## 问题 3:
#
# > 栈是一种常用的数据结构，编译器中通常使用栈来实现表达式求值。
# >
# > 以表达式 $3+5 \times 8-6$​ 为例。编译器使用两个栈来完成运算，即一个栈保持操作数，另一个栈保存运算符。
# >
# > 1. 从左向右遍历表达式，遇到数字就压入操作数栈；
# >
# > 2. 遇到运算符，就与运算符栈的栈顶元素进行比较。如果比运算符栈顶元素的优先级高，就将当前运算符压入栈；如果比运算符栈顶元素的优先级低或者相同，从运算符栈中取栈顶运算符，从操作数栈的栈顶取 2 个操作数，然后进行计算，再把计算完的结果压入操作数栈，继续比较。
# >
# > 下图是 $3+5 \times 8-6$  这个表达式的计算过程：
#
# ![figure](./fig/hw2q3.png)
#
# 根据上述原理，请设计一个算法完成表达式的运算，当输入为表达式字符串，返回对应的计算结果。分析算法设计思路，计算时间复杂度，并基于python编程实现
#
# **note：**
#
# 1. 假设输入的表达式只会出现加（“+”），减 “-”， 乘“*”，除 “/” 四个运算符, 表达式中只会出现正整数
# 2. python中` str.isdigit()`函数可以判断字符串str是否为数字，
#
#
#
# e.g. :
# ---
#
# 1. 输入：“$3+5 * 8 -6$”   输出：37
#
# 2. 输入：“$34+13*9 + 44-12/3$”  输出：191

# %% [markdown]
# idea：算法设计与实现
#
# 数据结构包括操作数栈：存储表达式中的数字。运算符栈：存储表达式中的运算符（+, -, *, /）。
#
# 定义字典 priority 控制运算顺序，确保先乘除后加减：priority = {'+': 1, '-': 1, '*': 2, '/': 2}
#
# 核心步骤
#
# 遍历表达式，若当前字符是数字（包括多位数），将其转换为整数并压入操作数栈。
# 若当前字符是运算符，若当前运算符优先级不高于运算符栈顶元素，则弹出栈顶运算符，结合操作数栈顶两个元素进行计算，结果压回操作数栈。将当前运算符压入运算符栈。
#
# 最终遍历结束后，依次弹出运算符栈中剩余运算符并计算，直到栈为空。
#
# 操作数栈中唯一元素即为最终结果。
#
# 时间复杂度分析
#
# 每个字符最多被压入和弹出一次，因此总时间复杂度为 $O(n)$，其中 n 是表达式的长度。

# %%
# add your idea here
def evaluate_expression(expression):
    # 定义运算符优先级
    priority = {'+': 1, '-': 1, '*': 2, '/': 2}

    def apply_operator(operands, operator):
        b = operands.pop()
        a = operands.pop()
        if operator == '+':
            return a + b
        elif operator == '-':
            return a - b
        elif operator == '*':
            return a * b
        elif operator == '/':
            return a // b  # 使用整数除法

    operand_stack = []
    operator_stack = []

    i = 0
    while i < len(expression):
        if expression[i].isdigit():
            # 处理多位数
            num = 0
            while i < len(expression) and expression[i].isdigit():
                num = num * 10 + int(expression[i])
                i += 1
            operand_stack.append(num)
            continue

        if expression[i] in priority:
            # 根据优先级判断是否计算
            while (operator_stack and operator_stack[-1] in priority and
                   priority[expression[i]] <= priority[operator_stack[-1]]):
                operand_stack.append(apply_operator(operand_stack, operator_stack.pop()))
            operator_stack.append(expression[i])
        # 跳过空格等非数字/运算符字符
        i += 1

    # 处理剩余运算符
    while operator_stack:
        operand_stack.append(apply_operator(operand_stack, operator_stack.pop()))

    return operand_stack[0]

# 测试用例
print(evaluate_expression("3+5*8-6")) 
print(evaluate_expression("34+13*9 + 44-12/3")) 

# your algorithm time complexity is: O(n)
# Out:
# 37
# 191

# %% [markdown]
# ## 问题 4:
#
# > 星球碰撞问题：现有n个星球，在同一条直线上运行，如数组A所示，元素的绝对值表示星球的质量，负数表示星球自右向左运动，正数表示星球自左向右运动，当两个星球相撞的时候，质量小的会消失，大的保持不变，**质量相同的两个星球碰撞后自右向左运动的星球消失，自左向右的星球保持不变**，假设所有星球的速度大小相同。
# >
# > $ A=[23,-8, 9, -3, -7, 9, -23, 22] $
#
# 请设计一个算法模拟星球的运行情况，输出最终的星球存续情况（输出一个数组），分析算法设计思路，计算时间复杂度，并基于python编程实现。
#
# e.g.
# ---
# 1.  输入： A=[-3,-6,2,8, 5,-8,9,-2,1]， 输出：[-3, -6, 2, 8, 9, 1]
#
# 2. 输入：A=[23,-8, 9, -3, -7, 9, -23, 22], 输出：[23, 22]

# %% [markdown]
# idea:算法设计与实现
#
# 使用栈模拟碰撞,栈用于保存未发生碰撞的星球。每次处理一个星球时，若其可能与栈顶星球碰撞，则进行比较并处理碰撞。只有当当前星球是负数（向左运动）且栈顶星球是正数（向右运动）时才会发生碰撞。
#
# 若栈顶星球质量大于当前星球质量：当前星球被销毁。
#
# 若栈顶星球质量等于当前星球质量：当前星球被销毁，栈顶星球保留。
#
# 若栈顶星球质量小于当前星球质量：栈顶星球被销毁，继续比较下一个栈顶星球。
#
# 时间复杂度分析
#
# 时间复杂度：$O(n)$，每个星球最多被压入和弹出栈一次。

# %%
# add your idea here
def asteroidCollision(asteroids):
    stack = []
    for aster in asteroids:
        if not stack or aster > 0:
            stack.append(aster)
        else:
            alive = True
            while alive and stack and stack[-1] > 0:
                top = stack[-1]
                if top > -aster:
                    alive = False
                elif top < -aster:
                    stack.pop()
                else:
                    # 质量相等，当前星球被销毁，栈顶星球保留
                    alive = False
            if alive:
                stack.append(aster)
    return stack

# 示例测试
print(asteroidCollision([-3, -6, 2, 8, 5, -8, 9, -2, 1])) 
print(asteroidCollision([23, -8, 9, -3, -7, 9, -23, 22]))  

# your algorithm time complexity is: O(n)
# Out:
# [-3, -6, 2, 8, 9, 1]
# [23, 22]

# %% [markdown]
# ## 问题 5
#
# > 给定一个无序数组nums=[9,-3,-10,0,9,7,33]，请建立一个二叉搜索树存储数组中的所有元素，之后删除二叉树中的元素“0”，再使用中序遍历输出二叉搜索树中的所有元素。
#
# 使用python编程完成上述任务，并计算时间复杂度

# %% [markdown]
# idea:
# 算法设计与实现
#
# 首先是二叉搜索树的构建，使用递归方式插入节点，确保每个节点的左子树小于当前节点，右子树大于等于当前节点。对于重复元素（如示例中的两个 9），插入到右子树中以保持中序遍历的有序性。
#
# 删除节点时，删除操作分为三种情况处理：
#
# 无子节点：直接删除。
#
# 有一个子节点：用子节点替代当前节点。
#
# 有两个子节点：找到右子树的最小值节点，用其值替换当前节点的值，并删除该最小值节点。
#
# 中序遍历二叉搜索树可得到升序序列，删除指定节点后再次中序遍历以输出最终结果。
#
# 时间复杂度分析
#
# 构建二叉搜索树时，每次插入的时间复杂度为 $O(h)$，其中h是树的高度。最坏情况下（树退化为链表），总时间复杂度为 $O(n^2)$；平均情况下为 $O(nlogn)$。
#
# 删除操作的时间复杂度为 $O(h)$，与插入相同。
#
# 中序遍历所有节点，时间复杂度为 $O(n)$。
#
# 总时间复杂度：
#
# 最坏情况下为 $O(n^2)$，平均情况下为 $O(nlogn)$。

# %%
# add your idea here
class TreeNode:
    def __init__(self, val):
        self.val = val
        self.left = None
        self.right = None

def insert_node(root, val):
    if not root:
        return TreeNode(val)
    if val < root.val:
        root.left = insert_node(root.left, val)
    else:
        root.right = insert_node(root.right, val)
    return root

def delete_node(root, key):
    if not root:
        return None
    if key < root.val:
        root.left = delete_node(root.left, key)
    elif key > root.val:
        root.right = delete_node(root.right, key)
    else:
        # Case 1: No child or one child
        if not root.left:
            return root.right
        if not root.right:
            return root.left
        # Case 2: Two children
        min_node = root.right
        while min_node.left:
            min_node = min_node.left
        root.val = min_node.val
        root.right = delete_node(root.right, min_node.val)
    return root

def inorder_traversal(root):
    result = []
    def helper(node):
        if not node:
            return
        helper(node.left)
        result.append(node.val)
        helper(node.right)
    helper(root)
    return result

def main():
    nums = [9, -3, -10, 0, 9, 7, 33]
    root = None
    for num in nums:
        root = insert_node(root, num)
    root = delete_node(root, 0)
    print(inorder_traversal(root)) 

if __name__ == "__main__":
    main()
    
# your algorithm time complexity is:O(nlogn)
# Out:
# [-10, -3, 7, 9, 9, 33]

# %% [markdown]
# ## 问题 6
#
# > 给定一个包含大写字母和小写字母的字符串 s ，返回 字符串包含的 **最长的回文子串的长度** 。请注意 区分大小写 。比如 "Aa" 不能当做一个回文字符串。
# >
#
# 请设计一个算法解决上述问题，只需要输出最长回文子串的长度，分析算法设计思路，计算时间复杂度，并基于python编程实现
#
# e.g. 输入： s="adccaccd"，  输出：7。 最长回文子串为："dccaccd", 长度为7

# %% [markdown]
# idea：算法设计与实现
#
# 回文串具有对称性，因此以每个字符为中心向两边扩展，找到最长的回文子串。
#
# 奇数长度回文：以单个字符为中心（如 aba 以 b 为中心）。
#
# 偶数长度回文：以两个相邻字符中间的位置为中心（如 abba 以中间两个 b 为中心）。
#
# 输入字符串 s 和左右指针 left、right。循环比较 s[left] 和 s[right]，若相等则向两边扩展。返回当前回文子串的长度：right - left - 1。
#
# 初始化 max_len 为 1（最短回文长度为 1）。遍历每个字符 i，分别处理奇数和偶数长度的回文情况。更新 max_len 为当前最大值。
#
# 时间复杂度分析
#
# 时间复杂度：$O(n²)$
#
# 每个字符作为中心点处理两次（奇数和偶数），每次扩展最多 $O(n)$ 时间。

# %%
# add your idea here
def longest_palindrome(s: str) -> int:
    if not s:
        return 0
    max_len = 1
    n = len(s)
    
    def expand(left: int, right: int) -> int:
        while left >= 0 and right < n and s[left] == s[right]:
            left -= 1
            right += 1
        return right - left - 1
    
    for i in range(n):
        len1 = expand(i, i)  # 奇数长度回文
        len2 = expand(i, i + 1)  # 偶数长度回文
        current_max = max(len1, len2)
        if current_max > max_len:
            max_len = current_max
    return max_len

print(longest_palindrome("adccaccd"))  
print(longest_palindrome("Aa"))        
print(longest_palindrome("cbbd"))      
print(longest_palindrome("babad"))   
 
# your algorithm time complexity is:O(n)
# Out:
# 7
# 1
# 2
# 3

# %% [markdown]
# ## 问题 7
#
# > 沿一条长河流分散着n座房子。你可以把这条河想象成一条轴，房子是由它们在这条轴上的坐标按顺序排列的。你的公司想在河边的特定地点设置手机基站，这样每户人家都在距离基站4公里的范围内。输入可以看作为一个升序数组，数组元素的取值为大于等于0的正整数，你需要输出最小基站的数目，基站的位置。
#
# 1. 给出一个时间复杂度为$O(n$) 的算法，使所使用的基站数量最小化，分析算法设计思路，使用python编程实现
# 2. 证明1.中算法产生了最优解决方案。
#
# e.g.
#
# 输入： [1, 5, 12, 33, 34,35]  输出：基站数目为3， 基站位置为[1，12，33]

# %% [markdown]
# idea：算法设计与实现
#
# 设计思路
# 每次在未被覆盖的第一个房子的位置放置基站，以最大化覆盖后续房子的数量。基站的覆盖范围为当前位置到当前位置+4公里，确保后续尽可能多的房子被覆盖。
#
# 遍历已排序的房屋数组。对于当前未被覆盖的第一个房子，放置基站并跳过所有被覆盖的房子。
#
# 时间复杂度分析
#
# 时间复杂度：$O(n)$，每个房子仅被访问一次。

# %%
# add your idea here
def min_towers(houses):
    towers = []
    i = 0
    n = len(houses)
    while i < n:
        # 在当前位置放置基站
        tower_pos = houses[i]
        towers.append(tower_pos)
        # 找到被覆盖的最远房子
        j = i + 1
        while j < n and houses[j] <= tower_pos + 4:
            j += 1
        i = j  # 移动到下一个未被覆盖的房子
    return len(towers), towers


houses = [1, 5, 12, 33, 34, 35]
num_towers, positions = min_towers(houses)
print(f"基站数目为{num_towers}，基站位置为{positions}")

# your algorithm time complexity is:o(n)
# Out:
# 基站数目为3，基站位置为[1, 12, 33]

# %% [markdown]
# ## 问题 8
#
# > 给定由n个正整数组成的一个集合$S = \{a_1, a_2，···，a_n\}$和一个正整数W，设计一个算法确定是否存在S的一个子集 $K \subseteq S$, 使K中所有数之和为 $W$, 如果存在返回“True”，否则返回“False”
#
# 请设计一个时间复杂度为$O(nW)$动态规划算法，解决上述问题，分析算法的设计思路，并且基于python编程实现（不需要输出子集）。
#
# e.g.
#
# 输入：S = {1,4,7,3,5}， W = 11，输出：True。   因为K可以是{4,7}。

# %% [markdown]
# idea：算法设计与实现
# 使用动态规划解决子集和问题，判断是否存在一个子集的和等于目标值W。
#
# dp[i][w] 表示前 i 个元素中是否存在一个子集的和等于 w。如果不选第 i 个元素，则 dp[i][w] = dp[i-1][w]。如果选第 i 个元素且 w >= a[i-1]，则 dp[i][w] = dp[i-1][w] or dp[i-1][w - a[i-1]]。
#
# dp[0][0] = True，表示没有元素时和为 0 的子集存在。其余 dp[0][w] = False（w > 0）。
#
# dp[n][W] 即为所求答案。
#
# 时间复杂度分析
#
# 时间复杂度：$O(nW)$，其中 n 是集合 S 的元素个数，W 是目标值。

# %%
# add your idea here
def subset_sum(S, W):
    n = len(S)
    # 初始化动态规划表
    dp = [[False] * (W + 1) for _ in range(n + 1)]
    dp[0][0] = True  # 基础情况：0个元素和为0
    
    # 填充动态规划表
    for i in range(1, n + 1):
        current = S[i - 1]  # 当前元素
        for w in range(W + 1):
            if w >= current:
                dp[i][w] = dp[i - 1][w] or dp[i - 1][w - current]
            else:
                dp[i][w] = dp[i - 1][w]
    
    return dp[n][W]


S = [1, 4, 7, 3, 5]
W = 11
print(subset_sum(S, W))  
# your algorithm time complexity is: O(nW)
# Out:
# True

# %% [markdown]
# ## 问题 9
#
# > 给定一个n个物品的集合。物体的重量为$w_1, w_2，…、w_n$，物品的价值分别是$v_1、v_2、…v_n$。给你**两个**重量为 $c$ 的背包。如果你带了一个东西，它可以放在一个背包里，也可以放在另一个背包里，但不能同时放在两个背包里。所有权重和价值都是正整数。
#
# 1. 设计一个时间复杂度为 $O(nc^2)$ 的动态规划算法，确定可以放入两个背包的物体的最大价值。分析算法设计思路，并基于python编程实现
# 2. \* 修改1中的算法，输出每个背包的内容（物品对应下标）。
#
# e.g.:
#
# 输入 V=[1,3,2,5,8,7], W=[1,3,2,5,8,7], c=7, 输出：最大价值=14，背包装的物品为：[6] [4，3] （同一个背包中物品装入顺序对结果无影响）

# %% [markdown]
# idea：动态规划解决双背包问题
#
# 问题1：
#
# 使用三维数组 dp[i][j][k] 表示前 i 个物品中，第一个背包容量为 j、第二个背包容量为 k 时的最大总价值。
#
# 不放入当前物品：dp[i][j][k] = dp[i-1][j][k]
#
# 放入第一个背包：dp[i][j][k] = max(dp[i][j][k], dp[i-1][j-w][k] + v)
#
# 放入第二个背包：dp[i][j][k] = max(dp[i][j][k], dp[i-1][j][k-w] + v)
#
# 初始化dp[0][0][0] = 0，其余初始化为负无穷。
#
# 遍历所有可能的 j 和 k 组合，找到最大总价值。
#
# 三维状态空间 dp[n+1][c+1][c+1] 的填充需要三重循环，时间复杂度为 $O(nc^2)$。
# 符合题目要求的时间复杂度。
#
# 问题2使用路径回溯
#
# 遍历所有 j 和 k 组合，找到最大总价值对应的状态 (j, k)。
#
# 从最终状态 (j, k) 开始，逐个物品回溯，判断每个物品是否被放入第一个背包、第二个背包或未被放入。根据回溯结果记录每个背包中的物品索引。
#
# 回溯仅需遍历 n 个物品，每次操作为常数时间，因此复杂度为 $O(n)$。
#
# 在$nc^2$的主导下，$O(n)$ 可忽略, 最终时间复杂度依旧为 $O(nc^2)$。

# %%
# add your idea here
def knapsack_two(W, V, c):
    n = len(W)
    INF = float('-inf')
    # 初始化三维动态规划数组
    dp = [[[INF] * (c + 1) for _ in range(c + 1)] for _ in range(n + 1)]
    dp[0][0][0] = 0  # 初始状态：两个背包都未装任何物品，总价值为0

    # 动态规划填充数组
    for i in range(1, n + 1):
        w = W[i - 1]
        v = V[i - 1]
        for j in range(c + 1):
            for k in range(c + 1):
                # 不放入当前物品
                dp[i][j][k] = dp[i - 1][j][k]
                # 放入第一个背包
                if j >= w:
                    dp[i][j][k] = max(dp[i][j][k], dp[i - 1][j - w][k] + v)
                # 放入第二个背包
                if k >= w:
                    dp[i][j][k] = max(dp[i][j][k], dp[i - 1][j][k - w] + v)

    # 找到最大总价值
    max_val = 0
    for j in range(c + 1):
        for k in range(c + 1):
            if dp[n][j][k] > max_val:
                max_val = dp[n][j][k]
    return max_val


if __name__ == "__main__":
    W = [1, 3, 2, 5, 8, 7]  # 物品重量
    V = [1, 3, 2, 5, 8, 7]  # 物品价值
    c = 7  # 背包容量

    # 计算最大价值
    max_value = knapsack_two(W, V, c)

    print(f"最大价值: {max_value}")
# your algorithm time complexity is: O(nc^2)
# Out:
# 最大价值: 14

# %%
# add your idea here
def knapsack_two(W, V, c):
    n = len(W)
    INF = float('-inf')
    # 初始化三维动态规划数组
    dp = [[[INF] * (c + 1) for _ in range(c + 1)] for _ in range(n + 1)]
    dp[0][0][0] = 0  # 初始状态：两个背包都未装任何物品，总价值为0

    # 动态规划填充数组
    for i in range(1, n + 1):
        w = W[i - 1]
        v = V[i - 1]
        for j in range(c + 1):
            for k in range(c + 1):
                # 不放入当前物品
                dp[i][j][k] = dp[i - 1][j][k]
                # 放入第一个背包
                if j >= w:
                    dp[i][j][k] = max(dp[i][j][k], dp[i - 1][j - w][k] + v)
                # 放入第二个背包
                if k >= w:
                    dp[i][j][k] = max(dp[i][j][k], dp[i - 1][j][k - w] + v)
    return dp


def backtrack(W, V, c, dp):
    n = len(W)
    # 找到最大总价值对应的状态
    max_val = 0
    final_j, final_k = 0, 0
    for j in range(c + 1):
        for k in range(c + 1):
            if dp[n][j][k] > max_val:
                max_val = dp[n][j][k]
                final_j, final_k = j, k

    # 回溯路径
    current_j = final_j
    current_k = final_k
    backpack1 = []  # 第一个背包的物品索引（0-based）
    backpack2 = []  # 第二个背包的物品索引（0-based）

    for i in range(n, 0, -1):
        w = W[i - 1]
        v = V[i - 1]
        # 检查是否未被选中
        if dp[i][current_j][current_k] == dp[i - 1][current_j][current_k]:
            continue
        else:
            # 检查是否放入第一个背包
            if current_j >= w and dp[i][current_j][current_k] == dp[i - 1][current_j - w][current_k] + v:
                backpack1.append(i - 1)
                current_j -= w
            # 检查是否放入第二个背包
            elif current_k >= w and dp[i][current_j][current_k] == dp[i - 1][current_j][current_k - w] + v:
                backpack2.append(i - 1)
                current_k -= w

    # 将索引转换为1-based
    backpack1 = [idx + 1 for idx in backpack1]
    backpack2 = [idx + 1 for idx in backpack2]

    return backpack1, backpack2, max_val


if __name__ == "__main__":
    W = [1, 3, 2, 5, 8, 7]  # 物品重量
    V = [1, 3, 2, 5, 8, 7]  # 物品价值
    c = 7  # 背包容量

    # 计算动态规划表
    dp = knapsack_two(W, V, c)
    # 回溯路径，获取每个背包中的物品
    bag1, bag2, max_value = backtrack(W, V, c, dp)

    print(f"最大价值: {max_value}")
    print(f"背包装的物品为: [{bag1}] [{bag2}]")
    
# your algorithm time complexity is:O(nc^2)
# Out:
# 最大价值: 14
# 背包装的物品为: [[6]] [[4, 3]]

# %% [markdown]
# ## 问题 10
#
# > 给定两个字符串 $x[1..n]$ 和 $y[1..m]$，我们想通过以下操作将 $x$ 变换为 $y$ :
# >
# > **插入**：在 $x$ 中插入一个字符(在任何位置)；**删除**：从 $x$ 中删除一个字符(在任何位置)； **替换**：用另一个字符替换 $x$ 中的一个字符。
# >
# > 例如: $x = abcd$, $y = bcfe$，
# >
# > - 将 $x$ 转换为 $y$ 的一种可能方法是：1. 删除 $x$ 开头的 $a$, $x$变成 $bcd$； 2. 将 $x$ 中的字符 $d$ 替换为字符 $f$。$x$ 变成 $bcf$； 3. 在 $x$ 的末尾插入字符 $e$。$x$ 变成 $bcfe$。
# >
# > - 另一种可能的方法：1. 删除 $x$ 开头的 $a$,  $x$ 变成 $bcd$； 2. 在 $x$ 中字符 $d$ 之前插入字符 $f$。$x$ 变成 $bcfd$。3. 将 $x$ 中的字符 $d$ 替换为字符 $e$。$x$ 变成 $bcfe$。
#
# 设计一个时间复杂度为 $O(mn)$ 的算法，返回将 $x$ 转换为 $y$ 所需的最少操作次数。分析算法设计思路，并基于python编程实现。

# %% [markdown]
# idea：
# 此问题要求将字符串 x 转换为 y，允许进行插入、删除和替换操作，目标是求出所需的最小操作次数，是经典的编辑距离问题，可使用动态规划高效求解。
#
# 定义一个二维数组 dp[i][j] 表示将字符串 x 的前 i 个字符转换为字符串 y 的前 j 个字符所需的最小操作次数。
#
# 状态转移方程
#
# 如果 x[i−1]==y[j−1]（字符相同）：dp[i][j]=dp[i−1][j−1]
#
# 如果 x[i−1] != y[j−1]（字符不同），则有三种操作选择：
#
# 替换：将 x[i−1] 替换为 y[j−1]，操作次数为 dp[i−1][j−1]+1
#
# 删除：删除 x[i−1]，操作次数为 dp[i−1][j]+1
#
# 插入：在 x 中插入 y[j−1]，操作次数为 dp[i][j−1]+1
#
# 最后取三者中的最小值：dp[i][j]=1+min(dp[i−1][j−1],dp[i−1][j],dp[i][j−1])
#
# 时间复杂度分析
#
# 状态数为 (n+1)×(m+1)，每个状态的转移时间为常数 $O(1)$。
#
# 所以总体时间复杂度为 $O(mn)$

# %%
# add your idea here
def min_edit_distance(x: str, y: str) -> int:
    n, m = len(x), len(y)
    
    # 初始化动态规划表
    dp = [[0] * (m + 1) for _ in range(n + 1)]
    
    # 初始化边界条件
    for i in range(n + 1):
        dp[i][0] = i  # 删除所有字符
    for j in range(m + 1):
        dp[0][j] = j  # 插入所有字符
    
    # 动态规划填充表
    for i in range(1, n + 1):
        for j in range(1, m + 1):
            if x[i - 1] == y[j - 1]:
                dp[i][j] = dp[i - 1][j - 1]
            else:
                dp[i][j] = 1 + min(
                    dp[i - 1][j - 1],   # 替换
                    dp[i - 1][j],       # 删除
                    dp[i][j - 1]        # 插入
                )
    
    return dp[n][m]

if __name__ == "__main__":
    x = "abcd"
    y = "bcfe"
    result = min_edit_distance(x, y)
    print(f"将 {x} 转换为 {y} 所需的最小操作次数为: {result}")
    
# your algorithm time complexity is: O(mn)
# Out:
# 将 abcd 转换为 bcfe 所需的最小操作次数为: 3
